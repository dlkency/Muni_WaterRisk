# %%
import ast
import pandas as pd

# %% [markdown]
# # Import Census county lat/long

# %%
df=pd.read_table('2021_Gaz_counties_national.txt',  sep = "\t")
geocode = df.iloc[:,[0,3,8,9]]
geocode
# Out:
#      USPS                 NAME   INTPTLAT  \
# 0      AL       Autauga County  32.532237
# 1      AL       Baldwin County  30.659218
# 2      AL       Barbour County  31.870253
# 3      AL          Bibb County  33.015893
# 4      AL        Blount County  33.977358
# ...   ...                  ...        ...
# 3216   PR  Vega Baja Municipio  18.455128
# 3217   PR    Vieques Municipio  18.125418
# 3218   PR   Villalba Municipio  18.130718
# 3219   PR    Yabucoa Municipio  18.059858
# 3220   PR      Yauco Municipio  18.085669
#
#       INTPTLONG
# 0                                            -86.646440
# 1                                            -87.746067
# 2                                            -85.405104
# 3                                            -87.127148
# 4                                            -86.566440
# ...                                                 ...
# 3216                                         -66.397883
# 3217                                         -65.432474
# 3218                                         -66.472244
# 3219                                         -65.859871
# 3220                                         -66.857901
#
# [3221 rows x 4 columns]

# %% [markdown]
# * Remove VA: Fairfax city since there is also a county in VA that is Fairfax. This is for matching with Bloomberg bond yeild dataset

# %%
geocode = geocode[geocode["NAME"].str.contains("Fairfax city")==False]
geocode
# Out:
#      USPS                 NAME   INTPTLAT  \
# 0      AL       Autauga County  32.532237
# 1      AL       Baldwin County  30.659218
# 2      AL       Barbour County  31.870253
# 3      AL          Bibb County  33.015893
# 4      AL        Blount County  33.977358
# ...   ...                  ...        ...
# 3216   PR  Vega Baja Municipio  18.455128
# 3217   PR    Vieques Municipio  18.125418
# 3218   PR   Villalba Municipio  18.130718
# 3219   PR    Yabucoa Municipio  18.059858
# 3220   PR      Yauco Municipio  18.085669
#
#       INTPTLONG
# 0                                            -86.646440
# 1                                            -87.746067
# 2                                            -85.405104
# 3                                            -87.127148
# 4                                            -86.566440
# ...                                                 ...
# 3216                                         -66.397883
# 3217                                         -65.432474
# 3218                                         -66.472244
# 3219                                         -65.859871
# 3220                                         -66.857901
#
# [3220 rows x 4 columns]

# %%
geocode.to_csv('count_lat_long.csv')

# %% [markdown]
# * remove the last word in "NAME" to only keep county name. This is for matching with Bloomberg bond yield dataset

# %%
geocode['NAME'] = geocode['NAME'].str.rsplit(' ',1).str[0]
# geocode[['County', 'State']] = county_names
# geocode['NAME'] = geocode['NAME'].str.rsplit(' ',1).str[0]
# geocode['NAME'] = county_names
geocode
# Out:
# C:\Users\lidan\AppData\Local\Temp\ipykernel_20852\641721130.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   geocode['NAME'] = geocode['NAME'].str.rsplit(' ',1).str[0]
#      USPS       NAME   INTPTLAT  \
# 0      AL    Autauga  32.532237
# 1      AL    Baldwin  30.659218
# 2      AL    Barbour  31.870253
# 3      AL       Bibb  33.015893
# 4      AL     Blount  33.977358
# ...   ...        ...        ...
# 3216   PR  Vega Baja  18.455128
# 3217   PR    Vieques  18.125418
# 3218   PR   Villalba  18.130718
# 3219   PR    Yabucoa  18.059858
# 3220   PR      Yauco  18.085669
#
#       INTPTLONG
# 0                                            -86.646440
# 1                                            -87.746067
# 2                                            -85.405104
# 3                                            -87.127148
# 4                                            -86.566440
# ...                                                 ...
# 3216                                         -66.397883
# 3217                                         -65.432474
# 3218                                         -66.472244
# 3219                                         -65.859871
# 3220                                         -66.857901
#
# [3220 rows x 4 columns]

# %%
yield_2017 = pd.read_excel(r'data/2017_waterMuni.xlsx', sheet_name='Sheet1')
yield_2017.head()
# Out:
#        CUSIP                                        Issuer Name Insured Bonds  \
# 0  13063DAQ1                                State of California             N
# 1  13034ARW2  California Infrastructure & Economic Developme...             N
# 2  64986DDG7       New York State Environmental Facilities Corp             N
# 3  51219SFN3  Lakeside Water Control & Improvement District ...             Y
# 4  837545LL4                  South Dakota Conservancy District             N
#
#   State Code U.S. County Of Issuance  Mod Dur (Mid)  Iss Spd Wst Issue Date  \
# 0         CA          Sacramento, CA       3.029972    23.738276  9/12/2017
# 1         CA          Sacramento, CA       1.120080    -2.797638  3/23/2017
# 2         NY              Albany, NY       2.680928     6.733772  4/13/2017
# 3         TX              Travis, TX       1.048659    39.541356  12/1/2017
# 4         SD              Hughes, SD       3.657233     6.352814  8/23/2017
#
#                                         Bond Purpose  Cpn   Maturity  \
# 0   SCHOOL IMPS. WATER UTILITY IMPS. REFUNDING NOTES  4.0  11/1/2025
# 1                  GREEN PURPOSE WATER UTILITY IMPS.  5.0  10/1/2023
# 2  WATER UTILITY IMPS. CURRENT REFUNDING GREEN PU...  5.0  6/15/2025
# 3                    WATER UTILITY IMPS. SEWER IMPS.  3.0   9/1/2023
# 4  WATER UTILITY IMPS. SEWER IMPS. ADVANCE REFUNDING  5.0   8/1/2026
#
#    Mty Size  Yield at Issue  YTW Sprd to Mty at Iss        BVAL Mid YTM  \
# 0  31985000            1.85               23.738276  #N/A Authorization
# 1  39755000            1.77               -2.797638  #N/A Authorization
# 2  19725000            2.24                6.733772  #N/A Authorization
# 3    300000            2.25               39.541356  #N/A Authorization
# 4   6565000            1.86                6.352814  #N/A Authorization
#
#               Tax Prov Is Federal Taxable  MSRB Volume BBG Composite  \
# 0  FED & ST TAX-EXEMPT                  N      45000.0           AA-
# 1  FED & ST TAX-EXEMPT                  N      75000.0           AAA
# 2  FED & ST TAX-EXEMPT                  N     100000.0           AAA
# 3               FED BQ                  N     400000.0             A
# 4       FED TAX-EXEMPT                  N     435000.0           AAA
#
#    LQA Score
# 0         77
# 1         95
# 2         80
# 3         89
# 4         60

# %% [markdown]
# * parse string (column "U.S. County Of Issuance" in yield data) to prepare for matching

# %%
user_names = yield_2017['U.S. County Of Issuance'].str.split(pat = ',', expand = True)
yield_2017[['County', 'State']] = user_names
yield_17 = yield_2017.iloc[:,[1,2,3, 5,6,7,9,10,11,12,13,17,18,19,20]]
yield_17.head()
# Out:
#                                          Issuer Name Insured Bonds State Code  \
# 0                                State of California             N         CA
# 1  California Infrastructure & Economic Developme...             N         CA
# 2       New York State Environmental Facilities Corp             N         NY
# 3  Lakeside Water Control & Improvement District ...             Y         TX
# 4                  South Dakota Conservancy District             N         SD
#
#    Mod Dur (Mid)  Iss Spd Wst Issue Date  Cpn   Maturity  Mty Size  \
# 0       3.029972    23.738276  9/12/2017  4.0  11/1/2025  31985000
# 1       1.120080    -2.797638  3/23/2017  5.0  10/1/2023  39755000
# 2       2.680928     6.733772  4/13/2017  5.0  6/15/2025  19725000
# 3       1.048659    39.541356  12/1/2017  3.0   9/1/2023    300000
# 4       3.657233     6.352814  8/23/2017  5.0   8/1/2026   6565000
#
#    Yield at Issue  YTW Sprd to Mty at Iss  MSRB Volume BBG Composite  \
# 0            1.85               23.738276      45000.0           AA-
# 1            1.77               -2.797638      75000.0           AAA
# 2            2.24                6.733772     100000.0           AAA
# 3            2.25               39.541356     400000.0             A
# 4            1.86                6.352814     435000.0           AAA
#
#    LQA Score      County
# 0         77  Sacramento
# 1         95  Sacramento
# 2         80      Albany
# 3         89      Travis
# 4         60      Hughes

# %% [markdown]
# # Fuzzy match County within the Bloomberg dataset and County list from Census to fetch lat/long
# both county and state information are used for fuzzy match

# %%
yield_17.dtypes
# Out:
# Issuer Name                object
# Insured Bonds              object
# State Code                 object
# Mod Dur (Mid)             float64
# Iss Spd Wst               float64
# Issue Date                 object
# Cpn                       float64
# Maturity                   object
# Mty Size                    int64
# Yield at Issue            float64
# YTW Sprd to Mty at Iss    float64
# MSRB Volume               float64
# BBG Composite              object
# LQA Score                   int64
# County                     object
# dtype: object

# %%
yield_17.convert_dtypes().dtypes
# Out:
# Issuer Name                string
# Insured Bonds              string
# State Code                 string
# Mod Dur (Mid)             Float64
# Iss Spd Wst               Float64
# Issue Date                 string
# Cpn                       Float64
# Maturity                   string
# Mty Size                    Int64
# Yield at Issue            Float64
# YTW Sprd to Mty at Iss    Float64
# MSRB Volume                 Int64
# BBG Composite              string
# LQA Score                   Int64
# County                     string
# dtype: object

# %%
common = pd.merge(yield_17, geocode, how = 'left', left_on = ['State Code', 'County'], right_on = ['USPS', 'NAME'])
common
# Out:
#                                             Issuer Name Insured Bonds  \
# 0                                   State of California             N
# 1     California Infrastructure & Economic Developme...             N
# 2          New York State Environmental Facilities Corp             N
# 3     Lakeside Water Control & Improvement District ...             Y
# 4                     South Dakota Conservancy District             N
# ...                                                 ...           ...
# 2252              Robinson Township Municipal Authority             Y
# 2253              Robinson Township Municipal Authority             Y
# 2254                          City of Universal City TX             N
# 2255                          City of Universal City TX             N
# 2256                          City of Universal City TX             N
#
#      State Code  Mod Dur (Mid)  Iss Spd Wst Issue Date  Cpn   Maturity  \
# 0            CA       3.029972    23.738276  9/12/2017  4.0  11/1/2025
# 1            CA       1.120080    -2.797638  3/23/2017  5.0  10/1/2023
# 2            NY       2.680928     6.733772  4/13/2017  5.0  6/15/2025
# 3            TX       1.048659    39.541356  12/1/2017  3.0   9/1/2023
# 4            SD       3.657233     6.352814  8/23/2017  5.0   8/1/2026
# ...         ...            ...          ...        ...  ...        ...
# 2252         PA       2.595127    58.150669   4/6/2017  5.0  5/15/2025
# 2253         PA       3.449541    59.751077   4/6/2017  5.0  5/15/2026
# 2254         TX       2.904055    15.856208  6/15/2017  3.0   9/1/2025
# 2255         TX       1.990501    16.133220  6/15/2017  3.0   9/1/2024
# 2256         TX       1.050193    16.847885  6/15/2017  3.0   9/1/2023
#
#       Mty Size  Yield at Issue  YTW Sprd to Mty at Iss  MSRB Volume  \
# 0     31985000            1.85               23.738276      45000.0
# 1     39755000            1.77               -2.797638      75000.0
# 2     19725000            2.24                6.733772     100000.0
# 3       300000            2.25               39.541356     400000.0
# 4      6565000            1.86                6.352814     435000.0
# ...        ...             ...                     ...          ...
# 2252   1135000            2.76               58.150669      75000.0
# 2253   1195000            2.91               59.751077          NaN
# 2254    135000            1.80               15.856208          NaN
# 2255    130000            1.65               16.133220          NaN
# 2256    130000            1.50               16.847885          NaN
#
#      BBG Composite  LQA Score      County USPS        NAME   INTPTLAT  \
# 0              AA-         77  Sacramento   CA  Sacramento  38.450136
# 1              AAA         95  Sacramento   CA  Sacramento  38.450136
# 2              AAA         80      Albany   NY      Albany  42.588240
# 3                A         89      Travis   TX      Travis  30.239513
# 4              AAA         60      Hughes   SD      Hughes  44.384452
# ...            ...        ...         ...  ...         ...        ...
# 2252           NaN         75   Allegheny   PA   Allegheny  40.469757
# 2253           NaN         70   Allegheny   PA   Allegheny  40.469757
# 2254           NaN         68       Bexar   TX       Bexar  29.448671
# 2255           NaN         80       Bexar   TX       Bexar  29.448671
# 2256           NaN         89       Bexar   TX       Bexar  29.448671
#
#       INTPTLONG
# 0                                           -121.344329
# 1                                           -121.344329
# 2                                            -73.974010
# 3                                            -97.691270
# 4                                            -99.975684
# ...                                                 ...
# 2252                                         -79.980451
# 2253                                         -79.980451
# 2254                                         -98.520147
# 2255                                         -98.520147
# 2256                                         -98.520147
#
# [2257 rows x 19 columns]

# %%
common.to_csv('bondyield_lat_long.csv')

# %% [markdown]
# # Final file with yield and water stress data combined

# %%
final =pd.read_csv('Aqueduct_yield.csv')
final.head(3)
# Out:
#    Unnamed: 0      CUSIP                                   Issuer Name  \
# 0           0  13063DRE0                           State of California
# 1           1  13063DRD2                           State of California
# 2           2  64986DJE6  New York State Environmental Facilities Corp
#
#   State Code U.S. County Of Issuance  Mod Dur (Mid)  Iss Spd Wst  Issue Date  \
# 0         CA          Sacramento, CA       6.417251    62.431046  10/24/2019
# 1         CA          Sacramento, CA       3.911377    51.640944  10/24/2019
# 2         NY              Albany, NY       5.924750     6.440986   10/8/2019
#
#                                         Bond Purpose    Cpn  ...  \
# 0  PUBLIC FACILITIES WATER UTILITY IMPS. REFUNDIN...  2.500  ...
# 1  PUBLIC FACILITIES WATER UTILITY IMPS. REFUNDIN...  2.375  ...
# 2  REFUNDING BONDS WATER UTILITY IMPS. GREEN PURPOSE  5.000  ...
#
#   Yield at Issue  Spread to AAA BVAL (%)  YTW Sprd to Mty at Iss  \
# 0           2.40      #N/A Authorization               62.431046
# 1           2.20      #N/A Authorization               51.640944
# 2           1.52      #N/A Authorization                6.440986
#
#                     Tax Prov  MSRB Volume            matches  USPS  \
# 0  FED TAXABLE/ST TAX-EXEMPT    3015000.0  Sacramento County    CA
# 1  FED TAXABLE/ST TAX-EXEMPT       5000.0  Sacramento County    CA
# 2        FED & ST TAX-EXEMPT    1530000.0      Albany County    NY
#
#                 NAME   INTPTLAT  \
# 0  Sacramento County  38.450136
# 1  Sacramento County  38.450136
# 2      Albany County  42.588240
#
#   INTPTLONG
# 0                                        -121.344329
# 1                                        -121.344329
# 2                                         -73.974010
#
# [3 rows x 22 columns]

# %%
final.describe()
# Out:
#         Unnamed: 0  Mod Dur (Mid)  Iss Spd Wst          Cpn      Mty Size  \
# count  3155.000000    3151.000000  3141.000000  3154.000000  3.155000e+03
# mean   1577.000000       2.626932    29.820384     3.983413  1.401926e+06
# std     910.914376       1.691086    28.802876     1.103807  8.947806e+06
# min       0.000000       0.030533   -32.082063     0.050000  5.000000e+03
# 25%     788.500000       1.090829     8.930145     3.000000  1.400000e+05
# 50%    1577.000000       2.420315    25.503740     4.000000  3.400000e+05
# 75%    2365.500000       3.968940    46.752953     5.000000  9.150000e+05
# max    3154.000000       6.800639   342.019260     7.000000  3.500000e+08
#
#        Yield at Issue  YTW Sprd to Mty at Iss   MSRB Volume     INTPTLAT  \
# count     3154.000000             3141.000000  1.103000e+03  3154.000000
# mean         1.737766               29.824591  1.993418e+05    36.959521
# std          0.395905               28.801843  6.642356e+05     5.562748
# min          0.900000              -32.082063  2.000000e+03    22.012038
# 25%          1.450000                8.930145  3.000000e+04    30.789630
# 50%          1.700000               25.555959  6.000000e+04    37.681045
# 75%          2.000000               46.752953  1.500000e+05    42.171738
# max          5.600000              342.019260  1.113000e+07    48.069247
#
#        INTPTLONG
# count                                        3154.000000
# mean                                          -92.483087
# std                                            13.369741
# min                                          -159.705965
# 25%                                           -97.310639
# 50%                                           -94.733647
# 75%                                           -83.926558
# max                                           -70.164823

# %%
Unique_location_forWaterrisk = final.drop_duplicates(subset=['USPS', 'NAME'], keep='last')
Unique_location_forWaterrisk.to_excel('locationforAqudt.xlsx')

# %%
waterrisk = pd.read_csv('aqueduct_20220719.csv')
waterrisk['longitude'].nunique()
# Out:
# 279

# %%
import statsmodels.formula.api as sm
from sklearn import linear_model
import numpy as np

# %%
# final["Time_to_Maturity"] = 
final["Maturity"] =pd.to_datetime(final["Maturity"])
final["Issue Date"] =pd.to_datetime(final["Issue Date"])

final["Time_to_Maturity"] = (final["Maturity"] - final["Issue Date"])/np.timedelta64(1, 'Y')
final["Maturity"] = final["Maturity"].dt.year
# final

# %%
final
# Out:
#       Unnamed: 0      CUSIP                                   Issuer Name  \
# 0              0  13063DRE0                           State of California
# 1              1  13063DRD2                           State of California
# 2              2  64986DJE6  New York State Environmental Facilities Corp
# 3              3  306801N72                           Town of Falmouth MA
# 4              4  575829FB7           Massachusetts Clean Water Trust/The
# ...          ...        ...                                           ...
# 3150        3150  933008BN3                      Borough of Walnutport PA
# 3151        3151  933033UX8                            Town of Walpole MA
# 3152        3152  933033VA7                            Town of Walpole MA
# 3153        3153  933033VB5                            Town of Walpole MA
# 3154        3154  933033VC3                            Town of Walpole MA
#
#      State Code U.S. County Of Issuance  Mod Dur (Mid)  Iss Spd Wst  \
# 0            CA          Sacramento, CA       6.417251    62.431046
# 1            CA          Sacramento, CA       3.911377    51.640944
# 2            NY              Albany, NY       5.924750     6.440986
# 3            MA          Barnstable, MA       3.196302    -4.728995
# 4            MA             Suffolk, MA       3.609202     4.950507
# ...         ...                     ...            ...          ...
# 3150         PA         Northampton, PA       2.182782    64.189290
# 3151         MA             Norfolk, MA       0.802003    -1.616195
# 3152         MA             Norfolk, MA       3.480021    -1.929545
# 3153         MA             Norfolk, MA       4.298131    -2.891156
# 3154         MA             Norfolk, MA       5.082349     0.195233
#
#      Issue Date                                       Bond Purpose    Cpn  \
# 0    2019-10-24  PUBLIC FACILITIES WATER UTILITY IMPS. REFUNDIN...  2.500
# 1    2019-10-24  PUBLIC FACILITIES WATER UTILITY IMPS. REFUNDIN...  2.375
# 2    2019-10-08  REFUNDING BONDS WATER UTILITY IMPS. GREEN PURPOSE  5.000
# 3    2019-12-12  REFUNDING NOTES CURRENT REFUNDING WATER UTILIT...  5.000
# 4    2019-10-24      SEWER IMPS. WATER UTILITY IMPS. GREEN PURPOSE  5.000
# ...         ...                                                ...    ...
# 3150 2019-05-23                REFUNDING BONDS WATER UTILITY IMPS.  3.000
# 3151 2019-05-15                   WATER UTILITY IMPS. SCHOOL IMPS.  5.000
# 3152 2019-05-15                   WATER UTILITY IMPS. SCHOOL IMPS.  5.000
# 3153 2019-05-15                   WATER UTILITY IMPS. SCHOOL IMPS.  5.000
# 3154 2019-05-15                   WATER UTILITY IMPS. SCHOOL IMPS.  5.000
#
#       ...  Spread to AAA BVAL (%)  YTW Sprd to Mty at Iss  \
# 0     ...      #N/A Authorization               62.431046
# 1     ...      #N/A Authorization               51.640944
# 2     ...      #N/A Authorization                6.440986
# 3     ...      #N/A Authorization               -4.728995
# 4     ...      #N/A Authorization                4.950507
# ...   ...                     ...                     ...
# 3150  ...      #N/A Authorization               64.189290
# 3151  ...      #N/A Authorization               -1.616195
# 3152  ...      #N/A Authorization               -1.929545
# 3153  ...      #N/A Authorization               -2.891156
# 3154  ...      #N/A Authorization                0.195233
#
#                        Tax Prov MSRB Volume             matches USPS  \
# 0     FED TAXABLE/ST TAX-EXEMPT   3015000.0   Sacramento County   CA
# 1     FED TAXABLE/ST TAX-EXEMPT      5000.0   Sacramento County   CA
# 2           FED & ST TAX-EXEMPT   1530000.0       Albany County   NY
# 3           FED & ST TAX-EXEMPT    255000.0   Barnstable County   MA
# 4           FED & ST TAX-EXEMPT      5000.0      Suffolk County   MA
# ...                         ...         ...                 ...  ...
# 3150       FED BQ/ST TAX-EXEMPT         NaN  Northampton County   PA
# 3151       FED BQ/ST TAX-EXEMPT    120000.0      Norfolk County   MA
# 3152       FED BQ/ST TAX-EXEMPT    160000.0      Norfolk County   MA
# 3153       FED BQ/ST TAX-EXEMPT         NaN      Norfolk County   MA
# 3154       FED BQ/ST TAX-EXEMPT         NaN      Norfolk County   MA
#
#                     NAME   INTPTLAT  \
# 0      Sacramento County  38.450136
# 1      Sacramento County  38.450136
# 2          Albany County  42.588240
# 3      Barnstable County  41.706123
# 4         Suffolk County  42.338551
# ...                  ...        ...
# 3150  Northampton County  40.752791
# 3151      Norfolk County  42.171738
# 3152      Norfolk County  42.171738
# 3153      Norfolk County  42.171738
# 3154      Norfolk County  42.171738
#
#      INTPTLONG                                                                                                                 \
# 0                                           -121.344329
# 1                                           -121.344329
# 2                                            -73.974010
# 3                                            -70.164823
# 4                                            -71.018253
# ...                                                 ...
# 3150                                         -75.307447
# 3151                                         -71.181110
# 3152                                         -71.181110
# 3153                                         -71.181110
# 3154                                         -71.181110
#
#      Time_to_Maturity
# 0            9.938602
# 1            6.937856
# 2            9.686715
# 3            6.141125
# 4            6.770844
# ...               ...
# 3150         5.445697
# 3151         4.000082
# 3152         7.000828
# 3153         8.000164
# 3154         9.002238
#
# [3155 rows x 23 columns]

# %%
final_risk = pd.merge(final, waterrisk, how = 'left', left_on = ['INTPTLAT'], right_on = ['latitude'])
final_risk.head(3)
# Out:
#    Unnamed: 0      CUSIP                                   Issuer Name  \
# 0           0  13063DRE0                           State of California
# 1           1  13063DRD2                           State of California
# 2           2  64986DJE6  New York State Environmental Facilities Corp
#
#   State Code U.S. County Of Issuance  Mod Dur (Mid)  Iss Spd Wst Issue Date  \
# 0         CA          Sacramento, CA       6.417251    62.431046 2019-10-24
# 1         CA          Sacramento, CA       3.911377    51.640944 2019-10-24
# 2         NY              Albany, NY       5.924750     6.440986 2019-10-08
#
#                                         Bond Purpose    Cpn  ...  \
# 0  PUBLIC FACILITIES WATER UTILITY IMPS. REFUNDIN...  2.500  ...
# 1  PUBLIC FACILITIES WATER UTILITY IMPS. REFUNDIN...  2.375  ...
# 2  REFUNDING BONDS WATER UTILITY IMPS. GREEN PURPOSE  5.000  ...
#
#    w_awr_tex_rrr_raw  w_awr_tex_rrr_score  w_awr_tex_rrr_cat  \
# 0           0.637859             1.310914                1.0
# 1           0.637859             1.310914                1.0
# 2           0.584215             1.261548                1.0
#
#   w_awr_tex_rrr_label  w_awr_tex_rrr_weight_fraction w_awr_tex_tot_raw  \
# 0  Low - Medium (1-2)                       0.326531          1.604262
# 1  Low - Medium (1-2)                       0.326531          1.604262
# 2  Low - Medium (1-2)                       0.326531          0.751871
#
#    w_awr_tex_tot_score w_awr_tex_tot_cat w_awr_tex_tot_label  \
# 0             1.989952               1.0  Low - Medium (1-2)
# 1             1.989952               1.0  Low - Medium (1-2)
# 2             0.743294               0.0           Low (0-1)
#
#   w_awr_tex_tot_weight_fraction
# 0                      1.000000
# 1                      1.000000
# 2                      0.918367
#
# [3 rows x 294 columns]

# %% [markdown]
# # Water risk linear regression tests
# Physical risk quantity:
# bws:Baseline water stress
# bwd:Baseline water depletion
# iav:Interannual variability
# sev:Seasonal variability
# gtd:Groundwater table decline
# rfr:Riverine flood risk
# cfr:Coastal flood risk
# drr:Drought risk
#
# Physical risk quality:
# ucw:Untreated connected wastewater
# cep:Coastal eutrophication potential
#
# Regulatory and reputational risk:
# udw:Unimproved/no drinking water
# usa:Unimproved/no sanitation
# rri:Peak RepRisk country ESG risk index

# %%
y = final_risk["Iss Spd Wst"]
# y = final_risk["YTW Sprd to Mty at Iss"]
x1 = final_risk["bws_score"]

df = pd.DataFrame({'x1':x1, 'y':y})
model = sm.ols('y~x1', data=df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                   0.02485
# Date:                Tue, 26 Jul 2022   Prob (F-statistic):              0.875
# Time:                        14:22:45   Log-Likelihood:                -14845.
# No. Observations:                3109   AIC:                         2.969e+04
# Df Residuals:                    3107   BIC:                         2.971e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     29.9376      0.814     36.794      0.000      28.342      31.533
# x1            -0.0566      0.359     -0.158      0.875      -0.760       0.647
# ==============================================================================
# Omnibus:                     1223.126   Durbin-Watson:                   0.814
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12405.259
# Skew:                           1.578   Prob(JB):                         0.00
# Kurtosis:                      12.263   Cond. No.                         4.04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y = final_risk["Iss Spd Wst"]
x1 = final_risk["bws_score"]
x2 = final_risk['Mod Dur (Mid)']
x3 = final_risk['Cpn']
# x4 = final_risk['State Code']
df = pd.DataFrame({'x1':x1, 'y':y, 'x2':x2, 'x3':x3})
model = sm.ols('y~x1+x2+x3', data=df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.161
# Model:                            OLS   Adj. R-squared:                  0.160
# Method:                 Least Squares   F-statistic:                     198.7
# Date:                Tue, 26 Jul 2022   Prob (F-statistic):          7.08e-118
# Time:                        14:21:55   Log-Likelihood:                -14572.
# No. Observations:                3109   AIC:                         2.915e+04
# Df Residuals:                    3105   BIC:                         2.918e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     69.8671      1.906     36.659      0.000      66.130      73.604
# x1             0.1110      0.329      0.337      0.736      -0.535       0.757
# x2             0.6971      0.284      2.452      0.014       0.140       1.254
# x3           -10.5730      0.435    -24.331      0.000     -11.425      -9.721
# ==============================================================================
# Omnibus:                     1572.584   Durbin-Watson:                   0.876
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            30705.082
# Skew:                           1.945   Prob(JB):                         0.00
# Kurtosis:                      17.896   Cond. No.                         22.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(color_codes=True)
sns.regplot(x="bws_score", y="Iss Spd Wst", data=final_risk);

# %%
y = final_risk["Iss Spd Wst"]
x = final_risk["bwd_score"]
df = pd.DataFrame({'x':x, 'y':y})
model = sm.ols('y~x', data=df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.813
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):              0.178
# Time:                        16:26:47   Log-Likelihood:                -14844.
# No. Observations:                3109   AIC:                         2.969e+04
# Df Residuals:                    3107   BIC:                         2.970e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     30.6328      0.785     39.014      0.000      29.093      32.172
# x             -0.8796      0.653     -1.346      0.178      -2.161       0.401
# ==============================================================================
# Omnibus:                     1228.238   Durbin-Watson:                   0.811
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12433.937
# Skew:                           1.587   Prob(JB):                         0.00
# Kurtosis:                      12.269   Cond. No.                         2.74
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y = final_risk["Iss Spd Wst"]
x = final_risk["iav_score"]
df = pd.DataFrame({'x':x, 'y':y})
model = sm.ols('y~x', data=df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     24.68
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):           7.13e-07
# Time:                        16:27:16   Log-Likelihood:                -14833.
# No. Observations:                3109   AIC:                         2.967e+04
# Df Residuals:                    3107   BIC:                         2.968e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     36.3547      1.409     25.802      0.000      33.592      39.117
# x             -3.7310      0.751     -4.968      0.000      -5.204      -2.258
# ==============================================================================
# Omnibus:                     1246.913   Durbin-Watson:                   0.812
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12750.548
# Skew:                           1.614   Prob(JB):                         0.00
# Kurtosis:                      12.381   Cond. No.                         6.47
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y = final_risk["Iss Spd Wst"]
x = final_risk["gtd_score"]
df = pd.DataFrame({'x':x, 'y':y})
model = sm.ols('y~x', data=df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.361
# Date:                Tue, 19 Jul 2022   Prob (F-statistic):              0.244
# Time:                        16:32:30   Log-Likelihood:                -5334.7
# No. Observations:                1097   AIC:                         1.067e+04
# Df Residuals:                    1095   BIC:                         1.068e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     42.8510      2.837     15.106      0.000      37.285      48.417
# x             -1.6455      1.411     -1.166      0.244      -4.413       1.122
# ==============================================================================
# Omnibus:                      420.085   Durbin-Watson:                   0.834
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3097.498
# Skew:                           1.575   Prob(JB):                         0.00
# Kurtosis:                      10.606   Cond. No.                         7.38
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Drought risk is significant correlated with issuance spread
# rfr: Riverine flood risk
# y : Issuance spread to worst / Spread to maturity at issuance -- both are significant

# %%
y = final_risk["Iss Spd Wst"]
# y = final_risk['YTW Sprd to Mty at Iss']
x = final_risk["drr_score"]
df = pd.DataFrame({'x':x, 'y':y})
model = sm.ols('y~x', data=df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.054
# Model:                            OLS   Adj. R-squared:                  0.054
# Method:                 Least Squares   F-statistic:                     177.9
# Date:                Tue, 26 Jul 2022   Prob (F-statistic):           1.66e-39
# Time:                        14:25:31   Log-Likelihood:                -14759.
# No. Observations:                3109   AIC:                         2.952e+04
# Df Residuals:                    3107   BIC:                         2.953e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -8.2103      2.896     -2.835      0.005     -13.888      -2.532
# x             18.2582      1.369     13.338      0.000      15.574      20.942
# ==============================================================================
# Omnibus:                     1495.529   Durbin-Watson:                   0.836
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20503.664
# Skew:                           1.931   Prob(JB):                         0.00
# Kurtosis:                      14.973   Cond. No.                         14.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y = final_risk["Iss Spd Wst"]
x1 = final_risk["drr_score"]
x2 = final_risk['Mod Dur (Mid)']
x3 = final_risk['Cpn']
x4 = final_risk['Maturity']
x5 = final_risk['Time_to_Maturity']
x6 = final_risk['MSRB Volume']
# x6 = final_risk['State Code']
df = pd.DataFrame({'x1':x1, 'y':y, 'x2':x2, 'x3':x3, 'x4':x4,'x5':x5, 'x6':x6
                   # , 'x4':x4
                  })
model = sm.ols('y~x1+x2+x3+x4+x5+x6', data=df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.297
# Model:                            OLS   Adj. R-squared:                  0.293
# Method:                 Least Squares   F-statistic:                     75.38
# Date:                Tue, 26 Jul 2022   Prob (F-statistic):           1.61e-78
# Time:                        14:31:40   Log-Likelihood:                -4646.7
# No. Observations:                1076   AIC:                             9307.
# Df Residuals:                    1069   BIC:                             9342.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.654e+04   3994.336      4.140      0.000    8699.549    2.44e+04
# x1            13.0752      1.443      9.062      0.000      10.244      15.906
# x2            15.3633      2.980      5.155      0.000       9.516      21.211
# x3           -10.9590      0.682    -16.059      0.000     -12.298      -9.620
# x4            -8.1586      1.976     -4.128      0.000     -12.037      -4.281
# x5            -3.1968      2.070     -1.544      0.123      -7.259       0.866
# x6           6.62e-08   8.32e-07      0.080      0.937   -1.57e-06     1.7e-06
# ==============================================================================
# Omnibus:                      261.830   Durbin-Watson:                   1.624
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              875.550
# Skew:                           1.166   Prob(JB):                    7.53e-191
# Kurtosis:                       6.753   Cond. No.                     5.02e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.02e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(color_codes=True)
sns.regplot(x="drr_score", y="Iss Spd Wst", data=final_risk);

# %% [markdown]
# NOTE
# * cfr: Coastal flood risk

# %%
y = final_risk["Iss Spd Wst"]
x = final_risk["cfr_score"]
df = pd.DataFrame({'x':x, 'y':y})
model = sm.ols('y~x', data=df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     161.8
# Date:                Tue, 26 Jul 2022   Prob (F-statistic):           3.63e-36
# Time:                        14:33:59   Log-Likelihood:                -14766.
# No. Observations:                3109   AIC:                         2.954e+04
# Df Residuals:                    3107   BIC:                         2.955e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     32.1626      0.534     60.244      0.000      31.116      33.209
# x            -11.7702      0.925    -12.719      0.000     -13.585      -9.956
# ==============================================================================
# Omnibus:                     1498.087   Durbin-Watson:                   0.830
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22066.678
# Skew:                           1.911   Prob(JB):                         0.00
# Kurtosis:                      15.479   Cond. No.                         1.95
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y = final_risk["Iss Spd Wst"]
x1 = final_risk["cfr_score"]
x2 = final_risk['Mod Dur (Mid)']
x3 = final_risk['Cpn']
x4 = final_risk['Maturity']
x5 = final_risk['Time_to_Maturity']
x6 = final_risk['MSRB Volume']
# x6 = final_risk['State Code']
df = pd.DataFrame({'x1':x1, 'y':y, 'x2':x2, 'x3':x3, 'x4':x4,'x5':x5, 'x6':x6
                   # , 'x4':x4
                  })
model = sm.ols('y~x1+x2+x3+x4+x5+x6', data=df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.271
# Model:                            OLS   Adj. R-squared:                  0.267
# Method:                 Least Squares   F-statistic:                     66.16
# Date:                Tue, 26 Jul 2022   Prob (F-statistic):           5.33e-70
# Time:                        14:34:55   Log-Likelihood:                -4666.6
# No. Observations:                1076   AIC:                             9347.
# Df Residuals:                    1069   BIC:                             9382.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.665e+04   4069.565      4.092      0.000    8666.159    2.46e+04
# x1            -5.6401      0.889     -6.344      0.000      -7.385      -3.896
# x2            12.4719      3.014      4.138      0.000       6.558      18.386
# x3           -10.9374      0.699    -15.637      0.000     -12.310      -9.565
# x4            -8.2045      2.014     -4.075      0.000     -12.156      -4.253
# x5            -0.7537      2.082     -0.362      0.717      -4.839       3.332
# x6          2.419e-08   8.48e-07      0.029      0.977   -1.64e-06    1.69e-06
# ==============================================================================
# Omnibus:                      201.881   Durbin-Watson:                   1.577
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              549.012
# Skew:                           0.966   Prob(JB):                    6.08e-120
# Kurtosis:                       5.918   Cond. No.                     5.02e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.02e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## Riverine flood risk
#
# rfr: Riverine flood risk

# %%
y = final_risk["Iss Spd Wst"]
# y = final_risk["YTW Sprd to Mty at Iss"]
x = final_risk["rfr_score"]
df = pd.DataFrame({'x':x, 'y':y})
model = sm.ols('y~x', data=df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     108.8
# Date:                Tue, 26 Jul 2022   Prob (F-statistic):           4.63e-25
# Time:                        14:38:33   Log-Likelihood:                -14792.
# No. Observations:                3109   AIC:                         2.959e+04
# Df Residuals:                    3107   BIC:                         2.960e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     22.8943      0.836     27.398      0.000      21.256      24.533
# x              5.3291      0.511     10.431      0.000       4.327       6.331
# ==============================================================================
# Omnibus:                     1218.968   Durbin-Watson:                   0.841
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13221.204
# Skew:                           1.550   Prob(JB):                         0.00
# Kurtosis:                      12.615   Cond. No.                         3.42
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# x4 = final_risk['State Code']
y = final_risk["Iss Spd Wst"]
x1 = final_risk["rfr_score"]
x2 = final_risk['Mod Dur (Mid)']
x3 = final_risk['Cpn']
x4 = final_risk['Maturity']
x5 = final_risk['Time_to_Maturity']
# x6 = final_risk['MSRB Volume']
x6 = final_risk['State Code']
df = pd.DataFrame({'x1':x1, 'y':y, 'x2':x2, 'x3':x3, 'x4':x4,'x5':x5, 'x6':x6
                   # , 'x4':x4
                  })
model = sm.ols('y~x1+x2+x3+x4+x6', data=df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.426
# Model:                            OLS   Adj. R-squared:                  0.417
# Method:                 Least Squares   F-statistic:                     48.25
# Date:                Tue, 26 Jul 2022   Prob (F-statistic):               0.00
# Time:                        14:37:36   Log-Likelihood:                -13983.
# No. Observations:                3109   AIC:                         2.806e+04
# Df Residuals:                    3061   BIC:                         2.835e+04
# Df Model:                          47
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.342e+04   3072.114      4.367      0.000    7393.326    1.94e+04
# x6[T.AR]       0.7797      5.968      0.131      0.896     -10.922      12.481
# x6[T.AZ]     -16.2359      6.128     -2.650      0.008     -28.251      -4.221
# x6[T.CA]     -34.3537      4.125     -8.329      0.000     -42.441     -26.266
# x6[T.CO]     -31.8223      5.043     -6.310      0.000     -41.711     -21.934
# x6[T.CT]     -42.5790      5.284     -8.058      0.000     -52.940     -32.218
# x6[T.DC]     -47.8231     10.529     -4.542      0.000     -68.468     -27.178
# x6[T.FL]      -9.3484      5.465     -1.711      0.087     -20.063       1.366
# x6[T.GA]     -37.4825      7.634     -4.910      0.000     -52.451     -22.514
# x6[T.HI]    -2.33e-12   2.81e-13     -8.278      0.000   -2.88e-12   -1.78e-12
# x6[T.IA]     -32.7630      4.701     -6.969      0.000     -41.981     -23.545
# x6[T.IL]     -14.8909      4.407     -3.379      0.001     -23.532      -6.250
# x6[T.IN]     -25.2075      4.908     -5.137      0.000     -34.830     -15.585
# x6[T.KS]     -35.1250      5.144     -6.829      0.000     -45.210     -25.040
# x6[T.KY]     -18.2546      5.777     -3.160      0.002     -29.582      -6.928
# x6[T.LA]     -29.7072      7.036     -4.222      0.000     -43.502     -15.912
# x6[T.MA]     -56.7894      4.275    -13.283      0.000     -65.172     -48.406
# x6[T.MD]     -45.3392      4.719     -9.608      0.000     -54.592     -36.087
# x6[T.ME]     -56.1822      8.748     -6.422      0.000     -73.334     -39.030
# x6[T.MI]     -36.8993      5.151     -7.164      0.000     -46.998     -26.800
# x6[T.MN]     -37.4743      4.218     -8.885      0.000     -45.744     -29.204
# x6[T.MO]     -16.4141      5.443     -3.016      0.003     -27.086      -5.742
# x6[T.MS]     -19.2643      5.286     -3.644      0.000     -29.629      -8.900
# x6[T.MT]      32.7457      9.740      3.362      0.001      13.648      51.843
# x6[T.NC]     -42.1003      5.555     -7.579      0.000     -52.992     -31.208
# x6[T.NE]     -26.3769     10.545     -2.501      0.012     -47.053      -5.701
# x6[T.NH]     -12.5848      6.601     -1.907      0.057     -25.527       0.358
# x6[T.NJ]     -43.0359      4.946     -8.702      0.000     -52.733     -33.339
# x6[T.NM]     -32.9181      9.148     -3.598      0.000     -50.854     -14.982
# x6[T.NV]      38.8022      7.184      5.401      0.000      24.716      52.888
# x6[T.NY]     -57.6415      4.208    -13.699      0.000     -65.892     -49.391
# x6[T.OH]     -43.1555      5.165     -8.355      0.000     -53.284     -33.027
# x6[T.OK]     -32.3948      6.550     -4.946      0.000     -45.238     -19.552
# x6[T.OR]     -36.8201      5.602     -6.572      0.000     -47.805     -25.835
# x6[T.PA]     -22.3936      5.051     -4.433      0.000     -32.297     -12.490
# x6[T.RI]     -52.5640      7.026     -7.482      0.000     -66.340     -38.788
# x6[T.SC]     -40.9824      4.918     -8.333      0.000     -50.626     -31.339
# x6[T.SD]     -23.8757     10.521     -2.269      0.023     -44.506      -3.246
# x6[T.TN]     -28.9933      5.144     -5.637      0.000     -39.079     -18.908
# x6[T.TX]     -18.9508      3.911     -4.845      0.000     -26.619     -11.282
# x6[T.UT]     -36.1830      5.478     -6.605      0.000     -46.924     -25.442
# x6[T.VA]     -46.0026      6.846     -6.719      0.000     -59.427     -32.579
# x6[T.VT]     -53.0358      9.191     -5.770      0.000     -71.057     -35.015
# x6[T.WA]     -31.5809      4.975     -6.347      0.000     -41.336     -21.825
# x6[T.WI]     -24.5711      4.158     -5.909      0.000     -32.725     -16.418
# x1             2.4814      0.470      5.277      0.000       1.559       3.403
# x2             9.0609      1.764      5.136      0.000       5.602      12.520
# x3            -7.5633      0.421    -17.946      0.000      -8.390      -6.737
# x4            -6.5955      1.520     -4.340      0.000      -9.575      -3.616
# ==============================================================================
# Omnibus:                     1791.770   Durbin-Watson:                   0.924
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            64686.159
# Skew:                           2.128   Prob(JB):                         0.00
# Kurtosis:                      24.937   Cond. No.                     1.00e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.27e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ## Physical risk quality:
# ucw: Untreated connected wastewater
# cep:Coastal eutrophication potential

# %%
y = final_risk["Iss Spd Wst"]
# y = final_risk["YTW Sprd to Mty at Iss"]
x = final_risk["cep_score"]
df = pd.DataFrame({'x':x, 'y':y})
model = sm.ols('y~x', data=df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.043
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     138.0
# Date:                Tue, 26 Jul 2022   Prob (F-statistic):           3.24e-31
# Time:                        14:47:30   Log-Likelihood:                -14778.
# No. Observations:                3109   AIC:                         2.956e+04
# Df Residuals:                    3107   BIC:                         2.957e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     51.5926      1.919     26.883      0.000      47.830      55.356
# x             -7.6142      0.648    -11.749      0.000      -8.885      -6.343
# ==============================================================================
# Omnibus:                     1197.507   Durbin-Watson:                   0.804
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10605.561
# Skew:                           1.581   Prob(JB):                         0.00
# Kurtosis:                      11.478   Cond. No.                         12.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# x4 = final_risk['State Code']
y = final_risk["Iss Spd Wst"]
x1 = final_risk["ucw_score"]
x2 = final_risk['Mod Dur (Mid)']
x3 = final_risk['Cpn']
x4 = final_risk['Maturity']
x5 = final_risk['Time_to_Maturity']
# x6 = final_risk['MSRB Volume']
# x6 = final_risk['State Code']
df = pd.DataFrame({'x1':x1, 'y':y, 'x2':x2, 'x3':x3, 'x4':x4,'x5':x5, 'x6':x6
                   # , 'x4':x4
                  })
model = sm.ols('y~x1+x2+x3+x4', data=df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.166
# Model:                            OLS   Adj. R-squared:                  0.165
# Method:                 Least Squares   F-statistic:                     206.1
# Date:                Tue, 26 Jul 2022   Prob (F-statistic):          6.44e-122
# Time:                        14:40:17   Log-Likelihood:                -14596.
# No. Observations:                3114   AIC:                         2.920e+04
# Df Residuals:                    3110   BIC:                         2.923e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   9045.3188   1839.787      4.917      0.000    5438.000    1.27e+04
# x1          7966.0615   1620.269      4.917      0.000    4789.156    1.11e+04
# x2             9.8455      1.879      5.240      0.000       6.162      13.529
# x3           -10.0927      0.445    -22.678      0.000     -10.965      -9.220
# x4            -7.9098      1.616     -4.895      0.000     -11.078      -4.742
# ==============================================================================
# Omnibus:                     1601.783   Durbin-Watson:                   0.877
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            33374.140
# Skew:                           1.970   Prob(JB):                         0.00
# Kurtosis:                      18.547   Cond. No.                     1.84e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.78e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ## Regulatory and reputational risk:
#
# udw:Unimproved/no drinking water
# usa:Unimproved/no sanitation
# rri:Peak RepRisk country ESG risk index (should be excluded since it is a uniform score for United States)

# %%
y = final_risk["Iss Spd Wst"]
# y = final_risk["YTW Sprd to Mty at Iss"]
x = final_risk["udw_score"]
df = pd.DataFrame({'x':x, 'y':y})
model = sm.ols('y~x', data=df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.1067
# Date:                Tue, 26 Jul 2022   Prob (F-statistic):              0.744
# Time:                        14:42:57   Log-Likelihood:                -14845.
# No. Observations:                3109   AIC:                         2.969e+04
# Df Residuals:                    3107   BIC:                         2.971e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     29.9864      0.695     43.165      0.000      28.624      31.349
# x             -0.3560      1.090     -0.327      0.744      -2.493       1.781
# ==============================================================================
# Omnibus:                     1221.917   Durbin-Watson:                   0.815
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12402.601
# Skew:                           1.576   Prob(JB):                         0.00
# Kurtosis:                      12.263   Cond. No.                         2.59
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y = final_risk["Iss Spd Wst"]
# y = final_risk["YTW Sprd to Mty at Iss"]
x = final_risk["usa_score"]
df = pd.DataFrame({'x':x, 'y':y})
model = sm.ols('y~x', data=df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     3.150
# Date:                Tue, 26 Jul 2022   Prob (F-statistic):             0.0760
# Time:                        14:43:17   Log-Likelihood:                -14844.
# No. Observations:                3109   AIC:                         2.969e+04
# Df Residuals:                    3107   BIC:                         2.970e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     29.7005      0.520     57.161      0.000      28.682      30.719
# x              3.4128      1.923      1.775      0.076      -0.357       7.183
# ==============================================================================
# Omnibus:                     1222.398   Durbin-Watson:                   0.818
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12532.430
# Skew:                           1.573   Prob(JB):                         0.00
# Kurtosis:                      12.319   Cond. No.                         3.75
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
